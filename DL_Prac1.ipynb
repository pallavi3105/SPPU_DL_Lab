# %% [markdown]
# <a href="https://colab.research.google.com/github/pallavi3105/SPPU_DL_Lab/blob/main/DL_Prac1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment No 1**
# Study of deep learning packages.

# %% [markdown]
# **Tensorflow and keras **

# %%
import tensorflow as tf
print(tf.__version__)
import numpy as np
# Out:
# 2.14.0

# %%
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape =[1])])

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
x = np.array([1.0 , 2.0 , 3.0 , 4.0 , 6.0], dtype = float)
y = np.array([4.0 , 6.0 , 8.0 , 10.0 , 14.0],dtype= float)

# %%
model.fit(x , y , epochs = 7)
print(model.predict([13.0]))
# Out:
# Epoch 1/7
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4752
# Epoch 2/7
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4712
# Epoch 3/7
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4672
# Epoch 4/7
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4632
# Epoch 5/7
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4593
# Epoch 6/7
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4554
# Epoch 7/7
# ...
# 1/1 [==============================] - 0s 31ms/step
# [[31.111446]]

# %%
history = model.fit(x , y , epochs = 1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9.2750e-05
# Epoch 2/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 9.1965e-05
# Epoch 3/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9.1191e-05
# Epoch 4/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 9.0423e-05
# Epoch 5/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 8.9658e-05
# Epoch 6/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 8.8901e-05
# Epoch 7/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 8.8147e-05
# Epoch 8/1000
# 1/1 [==============================] - 0s 10ms/step - loss: 8.7402e-05
# Epoch 9/1000
# 1/1 [==============================] - 0s 8ms/step - loss: 8.6663e-05
# Epoch 10/1000
# 1/1 [==============================] - 0s 7ms/step - loss: 8.5932e-05
# Epoch 11/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 8.5209e-05
# Epoch 12/1000
# ...

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# **Pythorch**

# %%
# !pip install torch

# %%
import torch
print(torch.__version__)
# Out:
# 2.1.0+cu121

# %%
t1=torch.tensor([1, 2, 3, 4])
t2=torch.tensor([4, 5, 6, 7])

# %%
print("tensor2 + tensor1")
print(torch.add(t2, t1))
# Out:
# tensor2 + tensor1
# tensor([ 5,  7,  9, 11])
